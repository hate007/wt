# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

transactions = [
    ['butter', 'bread', 'milk'],
    ['butter', 'flour', 'milk', 'sugar'],
    ['butter', 'eggs', 'milk', 'salt'],
    ['eggs'],
    ['butter', 'flour', 'milk', 'salt']
]

df = pd.DataFrame(transactions)

print("Transactions Dataset:")
print(df)

te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)

df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = apriori(df_encoded, min_support=0.01, use_colnames=True)

association_rules_df = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

print("\nFrequent Itemsets:")
print(frequent_itemsets)
print("\nAssociation Rules:")
print(association_rules_df)
# Out:
# Transactions Dataset:
#         0      1     2      3
# 0  butter  bread  milk   None
# 1  butter  flour  milk  sugar
# 2  butter   eggs  milk   salt
# 3    eggs   None  None   None
# 4  butter  flour  milk   salt
#
# Frequent Itemsets:
#     support                      itemsets
# 0       0.2                       (bread)
# 1       0.8                      (butter)
# 2       0.4                        (eggs)
# 3       0.4                       (flour)
# 4       0.8                        (milk)
# 5       0.4                        (salt)
# 6       0.2                       (sugar)
# 7       0.2               (butter, bread)
# 8       0.2                 (bread, milk)
# 9       0.2                (butter, eggs)
# 10      0.4               (butter, flour)
# 11      0.8                (butter, milk)
# 12      0.4                (butter, salt)
# 13      0.2               (sugar, butter)
# 14      0.2                  (eggs, milk)
# 15      0.2                  (salt, eggs)
# 16      0.4                 (milk, flour)
# 17      0.2                 (salt, flour)
# 18      0.2                (sugar, flour)
# 19      0.4                  (salt, milk)
# 20      0.2                 (sugar, milk)
# 21      0.2         (butter, bread, milk)
# 22      0.2          (butter, eggs, milk)
# 23      0.2          (salt, butter, eggs)
# 24      0.4         (butter, milk, flour)
# 25      0.2         (butter, salt, flour)
# 26      0.2        (sugar, butter, flour)
# 27      0.4          (butter, salt, milk)
# 28      0.2         (sugar, butter, milk)
# 29      0.2            (salt, eggs, milk)
# 30      0.2           (salt, milk, flour)
# 31      0.2          (sugar, milk, flour)
# 32      0.2    (salt, butter, eggs, milk)
# 33      0.2   (butter, salt, milk, flour)
# 34      0.2  (sugar, butter, milk, flour)
#
# Association Rules:
#          antecedents            consequents  antecedent support  \
# 0            (bread)               (butter)                 0.2
# 1            (bread)                 (milk)                 0.2
# 2             (eggs)               (butter)                 0.4
# 3           (butter)                (flour)                 0.8
# 4            (flour)               (butter)                 0.4
# ..               ...                    ...                 ...
# 101   (sugar, flour)         (butter, milk)                 0.2
# 102  (butter, flour)          (sugar, milk)                 0.4
# 103    (milk, flour)        (sugar, butter)                 0.4
# 104          (sugar)  (butter, milk, flour)                 0.2
# 105          (flour)  (sugar, butter, milk)                 0.4
#
#      consequent support  support  confidence   lift  leverage  conviction  \
# 0                   0.8      0.2         1.0  1.250      0.04         inf
# 1                   0.8      0.2         1.0  1.250      0.04         inf
# 2                   0.8      0.2         0.5  0.625     -0.12         0.4
# 3                   0.4      0.4         0.5  1.250      0.08         1.2
# 4                   0.8      0.4         1.0  1.250      0.08         inf
# ..                  ...      ...         ...    ...       ...         ...
# 101                 0.8      0.2         1.0  1.250      0.04         inf
# 102                 0.2      0.2         0.5  2.500      0.12         1.6
# 103                 0.2      0.2         0.5  2.500      0.12         1.6
# 104                 0.4      0.2         1.0  2.500      0.12         inf
# 105                 0.2      0.2         0.5  2.500      0.12         1.6
#
#      zhangs_metric
# 0         0.250000
# 1         0.250000
# 2        -0.500000
# 3         1.000000
# 4         0.333333
# ..             ...
# 101       0.250000
# 102       1.000000
# 103       1.000000
# 104       0.750000
# 105       1.000000
#
# [106 rows x 10 columns]
