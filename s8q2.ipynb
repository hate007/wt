# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

df = pd.read_csv('market.csv')

print("Basic Information about the Dataset:")
print(df.info())

print("\nFirst few rows of the Dataset:")
print(df.head())

df.dropna(inplace=True)

te = TransactionEncoder()
items_list = df['Items'].apply(lambda x: x.split(',')).tolist()
te_ary = te.fit(items_list).transform(items_list)

df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = apriori(df_encoded, min_support=0.01, use_colnames=True)

association_rules_df = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

print("\nFrequent Itemsets:")
print(frequent_itemsets)
print("\nAssociation Rules:")
print(association_rules_df)
# Out:
# Basic Information about the Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Transaction_ID  50 non-null     int64
#  1   Items           50 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 928.0+ bytes
# None
#
# First few rows of the Dataset:
#    Transaction_ID                    Items
# 0               1          bread,milk,eggs
# 1               2             bread,cheese
# 2               3  milk,diapers,beer,bread
# 3               4        eggs,diapers,beer
# 4               5   milk,eggs,diapers,beer
#
# Frequent Itemsets:
#     support                        itemsets
# 0      0.50                          (beer)
# 1      0.44                         (bread)
# 2      0.32                        (cheese)
# 3      0.56                       (diapers)
# 4      0.58                          (eggs)
# 5      0.74                          (milk)
# 6      0.22                   (beer, bread)
# 7      0.08                  (cheese, beer)
# 8      0.26                 (diapers, beer)
# 9      0.28                    (beer, eggs)
# 10     0.34                    (beer, milk)
# 11     0.08                 (cheese, bread)
# 12     0.22                (diapers, bread)
# 13     0.18                   (eggs, bread)
# 14     0.30                   (milk, bread)
# 15     0.14               (cheese, diapers)
# 16     0.18                  (cheese, eggs)
# 17     0.24                  (cheese, milk)
# 18     0.30                 (diapers, eggs)
# 19     0.40                 (diapers, milk)
# 20     0.44                    (eggs, milk)
# 21     0.10          (diapers, beer, bread)
# 22     0.06             (beer, eggs, bread)
# 23     0.14             (beer, milk, bread)
# 24     0.04         (cheese, diapers, beer)
# 25     0.06            (cheese, beer, eggs)
# 26     0.04            (cheese, beer, milk)
# 27     0.14           (diapers, beer, eggs)
# 28     0.16           (diapers, beer, milk)
# 29     0.20              (beer, eggs, milk)
# 30     0.02        (cheese, diapers, bread)
# 31     0.02           (cheese, eggs, bread)
# 32     0.06           (cheese, milk, bread)
# 33     0.08          (diapers, eggs, bread)
# 34     0.14          (diapers, milk, bread)
# 35     0.14             (milk, eggs, bread)
# 36     0.06         (cheese, diapers, eggs)
# 37     0.10         (cheese, diapers, milk)
# 38     0.14            (cheese, eggs, milk)
# 39     0.20           (diapers, eggs, milk)
# 40     0.02    (diapers, beer, eggs, bread)
# 41     0.06    (diapers, beer, milk, bread)
# 42     0.04       (beer, eggs, milk, bread)
# 43     0.02   (cheese, diapers, beer, eggs)
# 44     0.04      (cheese, beer, eggs, milk)
# 45     0.08     (diapers, beer, eggs, milk)
# 46     0.02  (cheese, diapers, milk, bread)
# 47     0.02     (cheese, milk, eggs, bread)
# 48     0.04    (diapers, milk, eggs, bread)
# 49     0.04   (cheese, diapers, eggs, milk)
#
# Association Rules:
#                  antecedents   consequents  antecedent support  \
# 0                    (bread)        (beer)                0.44
# 1                     (beer)     (diapers)                0.50
# 2                     (beer)        (eggs)                0.50
# 3                     (beer)        (milk)                0.50
# 4                    (bread)     (diapers)                0.44
# 5                    (bread)        (milk)                0.44
# 6                   (cheese)        (eggs)                0.32
# 7                   (cheese)        (milk)                0.32
# 8                  (diapers)        (eggs)                0.56
# 9                     (eggs)     (diapers)                0.58
# 10                 (diapers)        (milk)                0.56
# 11                    (milk)     (diapers)                0.74
# 12                    (eggs)        (milk)                0.58
# 13                    (milk)        (eggs)                0.74
# 14             (beer, bread)        (milk)                0.22
# 15            (cheese, beer)     (diapers)                0.08
# 16            (cheese, beer)        (eggs)                0.08
# 17            (cheese, beer)        (milk)                0.08
# 18           (diapers, beer)        (eggs)                0.26
# 19              (beer, eggs)     (diapers)                0.28
# 20           (diapers, beer)        (milk)                0.26
# 21              (beer, eggs)        (milk)                0.28
# 22              (beer, milk)        (eggs)                0.34
# 23           (cheese, bread)        (milk)                0.08
# 24          (diapers, bread)        (milk)                0.22
# 25             (eggs, bread)        (milk)                0.18
# 26         (cheese, diapers)        (milk)                0.14
# 27            (cheese, eggs)        (milk)                0.18
# 28            (cheese, milk)        (eggs)                0.24
# 29           (diapers, eggs)        (milk)                0.30
# 30           (diapers, milk)        (eggs)                0.40
# 31    (diapers, beer, bread)        (milk)                0.10
# 32       (beer, eggs, bread)        (milk)                0.06
# 33   (cheese, diapers, beer)        (eggs)                0.04
# 34      (cheese, beer, eggs)        (milk)                0.06
# 35      (cheese, beer, milk)        (eggs)                0.04
# 36            (cheese, beer)  (eggs, milk)                0.08
# 37     (diapers, beer, eggs)        (milk)                0.14
# 38     (diapers, beer, milk)        (eggs)                0.16
# 39  (cheese, diapers, bread)        (milk)                0.02
# 40     (cheese, eggs, bread)        (milk)                0.02
# 41    (diapers, eggs, bread)        (milk)                0.08
# 42   (cheese, diapers, eggs)        (milk)                0.06
#
#     consequent support  support  confidence      lift  leverage  conviction  \
# 0                 0.50     0.22    0.500000  1.000000    0.0000    1.000000
# 1                 0.56     0.26    0.520000  0.928571   -0.0200    0.916667
# 2                 0.58     0.28    0.560000  0.965517   -0.0100    0.954545
# 3                 0.74     0.34    0.680000  0.918919   -0.0300    0.812500
# 4                 0.56     0.22    0.500000  0.892857   -0.0264    0.880000
# 5                 0.74     0.30    0.681818  0.921376   -0.0256    0.817143
# 6                 0.58     0.18    0.562500  0.969828   -0.0056    0.960000
# 7                 0.74     0.24    0.750000  1.013514    0.0032    1.040000
# 8                 0.58     0.30    0.535714  0.923645   -0.0248    0.904615
# 9                 0.56     0.30    0.517241  0.923645   -0.0248    0.911429
# 10                0.74     0.40    0.714286  0.965251   -0.0144    0.910000
# 11                0.56     0.40    0.540541  0.965251   -0.0144    0.957647
# 12                0.74     0.44    0.758621  1.025163    0.0108    1.077143
# 13                0.58     0.44    0.594595  1.025163    0.0108    1.036000
# 14                0.74     0.14    0.636364  0.859951   -0.0228    0.715000
# 15                0.56     0.04    0.500000  0.892857   -0.0048    0.880000
# 16                0.58     0.06    0.750000  1.293103    0.0136    1.680000
# 17                0.74     0.04    0.500000  0.675676   -0.0192    0.520000
# 18                0.58     0.14    0.538462  0.928382   -0.0108    0.910000
# 19                0.56     0.14    0.500000  0.892857   -0.0168    0.880000
# 20                0.74     0.16    0.615385  0.831601   -0.0324    0.676000
# 21                0.74     0.20    0.714286  0.965251   -0.0072    0.910000
# 22                0.58     0.20    0.588235  1.014199    0.0028    1.020000
# 23                0.74     0.06    0.750000  1.013514    0.0008    1.040000
# 24                0.74     0.14    0.636364  0.859951   -0.0228    0.715000
# 25                0.74     0.14    0.777778  1.051051    0.0068    1.170000
# 26                0.74     0.10    0.714286  0.965251   -0.0036    0.910000
# 27                0.74     0.14    0.777778  1.051051    0.0068    1.170000
# 28                0.58     0.14    0.583333  1.005747    0.0008    1.008000
# 29                0.74     0.20    0.666667  0.900901   -0.0220    0.780000
# 30                0.58     0.20    0.500000  0.862069   -0.0320    0.840000
# 31                0.74     0.06    0.600000  0.810811   -0.0140    0.650000
# 32                0.74     0.04    0.666667  0.900901   -0.0044    0.780000
# 33                0.58     0.02    0.500000  0.862069   -0.0032    0.840000
# 34                0.74     0.04    0.666667  0.900901   -0.0044    0.780000
# 35                0.58     0.04    1.000000  1.724138    0.0168         inf
# 36                0.44     0.04    0.500000  1.136364    0.0048    1.120000
# 37                0.74     0.08    0.571429  0.772201   -0.0236    0.606667
# 38                0.58     0.08    0.500000  0.862069   -0.0128    0.840000
# 39                0.74     0.02    1.000000  1.351351    0.0052         inf
# 40                0.74     0.02    1.000000  1.351351    0.0052         inf
# 41                0.74     0.04    0.500000  0.675676   -0.0192    0.520000
# 42                0.74     0.04    0.666667  0.900901   -0.0044    0.780000
#
#     zhangs_metric
# 0        0.000000
# 1       -0.133333
# 2       -0.066667
# 3       -0.150000
# 4       -0.176471
# 5       -0.132231
# 6       -0.043750
# 7        0.019608
# 8       -0.158163
# 9       -0.164456
# 10      -0.075630
# 11      -0.121622
# 12       0.058442
# 13       0.094406
# 14      -0.172727
# 15      -0.115385
# 16       0.246377
# 17      -0.342857
# 18      -0.094406
# 19      -0.142857
# 20      -0.214854
# 21      -0.047619
# 22       0.021212
# 23       0.014493
# 24      -0.172727
# 25       0.059233
# 26      -0.040179
# 27       0.059233
# 28       0.007519
# 29      -0.135802
# 30      -0.210526
# 31      -0.205882
# 32      -0.104762
# 33      -0.142857
# 34      -0.104762
# 35       0.437500
# 36       0.130435
# 37      -0.255411
# 38      -0.160000
# 39       0.265306
# 40       0.265306
# 41      -0.342857
# 42      -0.104762
