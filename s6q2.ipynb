# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
import pandas as pd


data = {
    'TID': [1, 2, 3, 4, 5],
    'Items': [['Bread', 'Milk'],
              ['Bread', 'Diaper', 'Beer', 'Eggs'],
              ['Milk', 'Diaper', 'Beer', 'Coke'],
              ['Bread', 'Milk', 'Diaper', 'Beer'],
              ['Bread', 'Milk', 'Diaper', 'Coke']]
}

df = pd.DataFrame(data)

te = TransactionEncoder()
te_ary = te.fit(df['Items']).transform(df['Items'])
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

print(df_encoded)
print("\n")

frequent_itemsets = apriori(df_encoded, min_support=0.2, use_colnames=True)

association_rules_df = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)

print("Frequent Itemsets:")
print(frequent_itemsets)
print("\nAssociation Rules:")
print(association_rules_df)
# Out:
#     Beer  Bread   Coke  Diaper   Eggs   Milk
# 0  False   True  False   False  False   True
# 1   True   True  False    True   True  False
# 2   True  False   True    True  False   True
# 3   True   True  False    True  False   True
# 4  False   True   True    True  False   True
#
#
# Frequent Itemsets:
#     support                     itemsets
# 0       0.6                       (Beer)
# 1       0.8                      (Bread)
# 2       0.4                       (Coke)
# 3       0.8                     (Diaper)
# 4       0.2                       (Eggs)
# 5       0.8                       (Milk)
# 6       0.4                (Bread, Beer)
# 7       0.2                 (Coke, Beer)
# 8       0.6               (Diaper, Beer)
# 9       0.2                 (Beer, Eggs)
# 10      0.4                 (Milk, Beer)
# 11      0.2                (Bread, Coke)
# 12      0.6              (Diaper, Bread)
# 13      0.2                (Bread, Eggs)
# 14      0.6                (Bread, Milk)
# 15      0.4               (Diaper, Coke)
# 16      0.4                 (Coke, Milk)
# 17      0.2               (Diaper, Eggs)
# 18      0.6               (Diaper, Milk)
# 19      0.4        (Diaper, Bread, Beer)
# 20      0.2          (Bread, Beer, Eggs)
# 21      0.2          (Bread, Milk, Beer)
# 22      0.2         (Diaper, Coke, Beer)
# 23      0.2           (Coke, Milk, Beer)
# 24      0.2         (Diaper, Beer, Eggs)
# 25      0.4         (Diaper, Milk, Beer)
# 26      0.2        (Diaper, Bread, Coke)
# 27      0.2          (Bread, Coke, Milk)
# 28      0.2        (Diaper, Bread, Eggs)
# 29      0.4        (Diaper, Bread, Milk)
# 30      0.4         (Diaper, Coke, Milk)
# 31      0.2  (Diaper, Bread, Beer, Eggs)
# 32      0.2  (Diaper, Bread, Milk, Beer)
# 33      0.2   (Diaper, Coke, Milk, Beer)
# 34      0.2  (Diaper, Bread, Coke, Milk)
#
# Association Rules:
#               antecedents            consequents  antecedent support  \
# 0                (Diaper)                 (Beer)                 0.8
# 1                  (Beer)               (Diaper)                 0.6
# 2                  (Eggs)                 (Beer)                 0.2
# 3                (Diaper)                (Bread)                 0.8
# 4                 (Bread)               (Diaper)                 0.8
# 5                  (Eggs)                (Bread)                 0.2
# 6                 (Bread)                 (Milk)                 0.8
# 7                  (Milk)                (Bread)                 0.8
# 8                  (Coke)               (Diaper)                 0.4
# 9                  (Coke)                 (Milk)                 0.4
# 10                 (Eggs)               (Diaper)                 0.2
# 11               (Diaper)                 (Milk)                 0.8
# 12                 (Milk)               (Diaper)                 0.8
# 13          (Bread, Beer)               (Diaper)                 0.4
# 14          (Bread, Eggs)                 (Beer)                 0.2
# 15           (Beer, Eggs)                (Bread)                 0.2
# 16                 (Eggs)          (Bread, Beer)                 0.2
# 17           (Coke, Beer)               (Diaper)                 0.2
# 18           (Coke, Beer)                 (Milk)                 0.2
# 19         (Diaper, Eggs)                 (Beer)                 0.2
# 20           (Beer, Eggs)               (Diaper)                 0.2
# 21                 (Eggs)         (Diaper, Beer)                 0.2
# 22           (Milk, Beer)               (Diaper)                 0.4
# 23          (Bread, Coke)               (Diaper)                 0.2
# 24          (Bread, Coke)                 (Milk)                 0.2
# 25         (Diaper, Eggs)                (Bread)                 0.2
# 26          (Bread, Eggs)               (Diaper)                 0.2
# 27                 (Eggs)        (Diaper, Bread)                 0.2
# 28         (Diaper, Coke)                 (Milk)                 0.4
# 29           (Coke, Milk)               (Diaper)                 0.4
# 30                 (Coke)         (Diaper, Milk)                 0.4
# 31  (Diaper, Bread, Eggs)                 (Beer)                 0.2
# 32   (Diaper, Beer, Eggs)                (Bread)                 0.2
# 33    (Bread, Beer, Eggs)               (Diaper)                 0.2
# 34         (Diaper, Eggs)          (Bread, Beer)                 0.2
# 35          (Bread, Eggs)         (Diaper, Beer)                 0.2
# 36           (Beer, Eggs)        (Diaper, Bread)                 0.2
# 37                 (Eggs)  (Diaper, Bread, Beer)                 0.2
# 38    (Bread, Milk, Beer)               (Diaper)                 0.2
# 39   (Diaper, Coke, Beer)                 (Milk)                 0.2
# 40     (Coke, Milk, Beer)               (Diaper)                 0.2
# 41           (Coke, Beer)         (Diaper, Milk)                 0.2
# 42  (Diaper, Bread, Coke)                 (Milk)                 0.2
# 43    (Bread, Coke, Milk)               (Diaper)                 0.2
# 44          (Bread, Coke)         (Diaper, Milk)                 0.2
#
#     consequent support  support  confidence      lift  leverage  conviction  \
# 0                  0.6      0.6        0.75  1.250000      0.12         1.6
# 1                  0.8      0.6        1.00  1.250000      0.12         inf
# 2                  0.6      0.2        1.00  1.666667      0.08         inf
# 3                  0.8      0.6        0.75  0.937500     -0.04         0.8
# 4                  0.8      0.6        0.75  0.937500     -0.04         0.8
# 5                  0.8      0.2        1.00  1.250000      0.04         inf
# 6                  0.8      0.6        0.75  0.937500     -0.04         0.8
# 7                  0.8      0.6        0.75  0.937500     -0.04         0.8
# 8                  0.8      0.4        1.00  1.250000      0.08         inf
# 9                  0.8      0.4        1.00  1.250000      0.08         inf
# 10                 0.8      0.2        1.00  1.250000      0.04         inf
# 11                 0.8      0.6        0.75  0.937500     -0.04         0.8
# 12                 0.8      0.6        0.75  0.937500     -0.04         0.8
# 13                 0.8      0.4        1.00  1.250000      0.08         inf
# 14                 0.6      0.2        1.00  1.666667      0.08         inf
# 15                 0.8      0.2        1.00  1.250000      0.04         inf
# 16                 0.4      0.2        1.00  2.500000      0.12         inf
# 17                 0.8      0.2        1.00  1.250000      0.04         inf
# 18                 0.8      0.2        1.00  1.250000      0.04         inf
# 19                 0.6      0.2        1.00  1.666667      0.08         inf
# 20                 0.8      0.2        1.00  1.250000      0.04         inf
# 21                 0.6      0.2        1.00  1.666667      0.08         inf
# 22                 0.8      0.4        1.00  1.250000      0.08         inf
# 23                 0.8      0.2        1.00  1.250000      0.04         inf
# 24                 0.8      0.2        1.00  1.250000      0.04         inf
# 25                 0.8      0.2        1.00  1.250000      0.04         inf
# 26                 0.8      0.2        1.00  1.250000      0.04         inf
# 27                 0.6      0.2        1.00  1.666667      0.08         inf
# 28                 0.8      0.4        1.00  1.250000      0.08         inf
# 29                 0.8      0.4        1.00  1.250000      0.08         inf
# 30                 0.6      0.4        1.00  1.666667      0.16         inf
# 31                 0.6      0.2        1.00  1.666667      0.08         inf
# 32                 0.8      0.2        1.00  1.250000      0.04         inf
# 33                 0.8      0.2        1.00  1.250000      0.04         inf
# 34                 0.4      0.2        1.00  2.500000      0.12         inf
# 35                 0.6      0.2        1.00  1.666667      0.08         inf
# 36                 0.6      0.2        1.00  1.666667      0.08         inf
# 37                 0.4      0.2        1.00  2.500000      0.12         inf
# 38                 0.8      0.2        1.00  1.250000      0.04         inf
# 39                 0.8      0.2        1.00  1.250000      0.04         inf
# 40                 0.8      0.2        1.00  1.250000      0.04         inf
# 41                 0.6      0.2        1.00  1.666667      0.08         inf
# 42                 0.8      0.2        1.00  1.250000      0.04         inf
# 43                 0.8      0.2        1.00  1.250000      0.04         inf
# 44                 0.6      0.2        1.00  1.666667      0.08         inf
#
#     zhangs_metric
# 0        1.000000
# 1        0.500000
# 2        0.500000
# 3       -0.250000
# 4       -0.250000
# 5        0.250000
# 6       -0.250000
# 7       -0.250000
# 8        0.333333
# 9        0.333333
# 10       0.250000
# 11      -0.250000
# 12      -0.250000
# 13       0.333333
# 14       0.500000
# 15       0.250000
# 16       0.750000
# 17       0.250000
# 18       0.250000
# 19       0.500000
# 20       0.250000
# 21       0.500000
# 22       0.333333
# 23       0.250000
# 24       0.250000
# 25       0.250000
# 26       0.250000
# 27       0.500000
# 28       0.333333
# 29       0.333333
# 30       0.666667
# 31       0.500000
# 32       0.250000
# 33       0.250000
# 34       0.750000
# 35       0.500000
# 36       0.500000
# 37       0.750000
# 38       0.250000
# 39       0.250000
# 40       0.250000
# 41       0.500000
# 42       0.250000
# 43       0.250000
# 44       0.500000
